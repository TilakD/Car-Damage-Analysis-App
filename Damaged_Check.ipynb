# %%
import os
os.environ["CUDA_VISIBLE_DEVICES"] = "2,3"

# %%
from keras.layers import Conv2D, MaxPooling2D, ZeroPadding2D
from keras.layers import Dense, Activation, Dropout, Flatten
from keras import optimizers
from keras.models import Sequential,load_model
from keras.preprocessing.image import ImageDataGenerator,load_img,img_to_array
import numpy as np 
from keras.callbacks import ModelCheckpoint, History
import os
import urllib
import matplotlib.pyplot as plt
# %matplotlib inline
import json
import seaborn as sns 
from keras import applications
from keras.models import Sequential, Model 
from keras.callbacks import ModelCheckpoint, LearningRateScheduler, TensorBoard, EarlyStopping
# Out:
# Using TensorFlow backend.

# %%
img_width = 256
img_height = 256
train_data_dir = 'training'
valid_data_dir = 'validation'
fine_tuned_model_path = 'ft_model.h5'
train_samples = [len(os.listdir(train_data_dir+'/'+i)) for i in sorted(os.listdir(train_data_dir))]
nb_train_samples = sum(train_samples)
print(nb_train_samples)
validation_samples = [len(os.listdir(valid_data_dir+'/'+i)) for i in sorted(os.listdir(valid_data_dir))]
nb_validation_samples = sum(validation_samples)
print(nb_validation_samples)
epochs=50
batch_size = 8
# Out:
# 1840
# 460

# %%
model = applications.DenseNet201(weights = "imagenet", include_top=False, input_shape = (img_width, img_height, 3))

for layer in model.layers[:25]:
    layer.trainable = False
    
x = model.output
x = Flatten()(x)
x = Dense(256, activation="relu")(x)
x = Dropout(0.5)(x)
x = Dense(256, activation="relu")(x)
predictions = Dense(1, activation="sigmoid")(x)

model_final = Model(input = model.input, output = predictions)

model_final.compile(loss = "binary_crossentropy", optimizer = optimizers.SGD(lr=0.00001, momentum=0.9), metrics=["accuracy"])

train_datagen = ImageDataGenerator(
rescale = 1./255,
horizontal_flip = True,
fill_mode = "nearest",
zoom_range = 0.2,
width_shift_range = 0.2,
height_shift_range=0.2,
shear_range=0.2,
rotation_range=40)

test_datagen = ImageDataGenerator(
rescale = 1./255,
horizontal_flip = True,
fill_mode = "nearest",
zoom_range = 0.2,
width_shift_range = 0.2,
height_shift_range=0.2,
shear_range=0.2,
rotation_range=40)

train_generator = train_datagen.flow_from_directory(
train_data_dir,
target_size = (img_height, img_width),
batch_size = batch_size, 
class_mode = "binary")

validation_generator = test_datagen.flow_from_directory(
valid_data_dir,
target_size = (img_height, img_width),
class_mode = "binary")

checkpoint = ModelCheckpoint("Damaged_densenet_final.h5", monitor='val_acc', verbose=1, save_best_only=True, save_weights_only=False, mode='auto', period=1)

#early = EarlyStopping(monitor='val_acc', min_delta=0, patience=10, verbose=1, mode='auto')

model_final.fit_generator(
train_generator,
samples_per_epoch = nb_train_samples,
epochs = epochs,
validation_data = validation_generator,
nb_val_samples = nb_validation_samples,
callbacks = [checkpoint]) #,early
# Out:
# /home/dtilak/.local/lib/python3.5/site-packages/ipykernel_launcher.py:13: UserWarning: Update your `Model` call to the Keras 2 API: `Model(outputs=Tensor("de..., inputs=Tensor("in...)`
#   del sys.path[0]
# Found 1840 images belonging to 2 classes.
# Found 460 images belonging to 2 classes.
# /home/dtilak/.local/lib/python3.5/site-packages/ipykernel_launcher.py:58: UserWarning: The semantics of the Keras 2 argument `steps_per_epoch` is not the same as the Keras 1 argument `samples_per_epoch`. `steps_per_epoch` is the number of batches to draw from the generator at each epoch. Basically steps_per_epoch = samples_per_epoch/batch_size. Similarly `nb_val_samples`->`validation_steps` and `val_samples`->`steps` arguments have changed. Update your method calls accordingly.
# /home/dtilak/.local/lib/python3.5/site-packages/ipykernel_launcher.py:58: UserWarning: Update your `fit_generator` call to the Keras 2 API: `fit_generator(<keras_pre..., steps_per_epoch=230, validation_data=<keras_pre..., validation_steps=460, epochs=50, callbacks=[<keras.ca...)`
# Epoch 1/50
# 230/230 [==============================] - 336s 1s/step - loss: 0.6587 - acc: 0.6234 - val_loss: 0.4952 - val_acc: 0.7672
#
# Epoch 00001: val_acc improved from -inf to 0.76721, saving model to Damaged_densenet_final.h5
# Epoch 2/50
# 230/230 [==============================] - 297s 1s/step - loss: 0.4974 - acc: 0.7663 - val_loss: 0.4217 - val_acc: 0.8111
#
# Epoch 00002: val_acc improved from 0.76721 to 0.81106, saving model to Damaged_densenet_final.h5
# Epoch 3/50
# 230/230 [==============================] - 298s 1s/step - loss: 0.4445 - acc: 0.7995 - val_loss: 0.3949 - val_acc: 0.8230
#
# Epoch 00003: val_acc improved from 0.81106 to 0.82298, saving model to Damaged_densenet_final.h5
# Epoch 4/50
# 230/230 [==============================] - 296s 1s/step - loss: 0.4230 - acc: 0.8250 - val_loss: 0.4260 - val_acc: 0.7960
#
# Epoch 00004: val_acc did not improve from 0.82298
# Epoch 5/50
# 230/230 [==============================] - 296s 1s/step - loss: 0.3871 - acc: 0.8326 - val_loss: 0.3561 - val_acc: 0.8402
#
# Epoch 00005: val_acc improved from 0.82298 to 0.84021, saving model to Damaged_densenet_final.h5
# Epoch 6/50
# 230/230 [==============================] - 297s 1s/step - loss: 0.3594 - acc: 0.8484 - val_loss: 0.3669 - val_acc: 0.8321
#
# Epoch 00006: val_acc did not improve from 0.84021
# Epoch 7/50
# 230/230 [==============================] - 296s 1s/step - loss: 0.3420 - acc: 0.8603 - val_loss: 0.3380 - val_acc: 0.8492
#
# Epoch 00007: val_acc improved from 0.84021 to 0.84922, saving model to Damaged_densenet_final.h5
# Epoch 8/50
# 230/230 [==============================] - 296s 1s/step - loss: 0.3395 - acc: 0.8576 - val_loss: 0.3931 - val_acc: 0.8167
#
# Epoch 00008: val_acc did not improve from 0.84922
# Epoch 9/50
# 230/230 [==============================] - 298s 1s/step - loss: 0.3447 - acc: 0.8549 - val_loss: 0.3106 - val_acc: 0.8665
#
# Epoch 00009: val_acc improved from 0.84922 to 0.86652, saving model to Damaged_densenet_final.h5
# Epoch 10/50
# 230/230 [==============================] - 298s 1s/step - loss: 0.3302 - acc: 0.8587 - val_loss: 0.3048 - val_acc: 0.8704
#
# Epoch 00010: val_acc improved from 0.86652 to 0.87040, saving model to Damaged_densenet_final.h5
# Epoch 11/50
# 230/230 [==============================] - 299s 1s/step - loss: 0.3284 - acc: 0.8647 - val_loss: 0.2815 - val_acc: 0.8829
#
# Epoch 00011: val_acc improved from 0.87040 to 0.88291, saving model to Damaged_densenet_final.h5
# Epoch 12/50
# 230/230 [==============================] - 298s 1s/step - loss: 0.3207 - acc: 0.8734 - val_loss: 0.2912 - val_acc: 0.8791
#
# Epoch 00012: val_acc did not improve from 0.88291
# Epoch 13/50
# 230/230 [==============================] - 297s 1s/step - loss: 0.3005 - acc: 0.8826 - val_loss: 0.3160 - val_acc: 0.8611
#
# Epoch 00013: val_acc did not improve from 0.88291
# Epoch 14/50
# 230/230 [==============================] - 298s 1s/step - loss: 0.3026 - acc: 0.8745 - val_loss: 0.2970 - val_acc: 0.8716
#
# Epoch 00014: val_acc did not improve from 0.88291
# Epoch 15/50
# 230/230 [==============================] - 298s 1s/step - loss: 0.3254 - acc: 0.8647 - val_loss: 0.2963 - val_acc: 0.8720
#
# Epoch 00015: val_acc did not improve from 0.88291
# Epoch 16/50
# 230/230 [==============================] - 300s 1s/step - loss: 0.2932 - acc: 0.8783 - val_loss: 0.3098 - val_acc: 0.8638
#
# Epoch 00016: val_acc did not improve from 0.88291
# Epoch 17/50
# 230/230 [==============================] - 298s 1s/step - loss: 0.2842 - acc: 0.8728 - val_loss: 0.2739 - val_acc: 0.8833
#
# Epoch 00017: val_acc improved from 0.88291 to 0.88333, saving model to Damaged_densenet_final.h5
# Epoch 18/50
# 230/230 [==============================] - 298s 1s/step - loss: 0.2760 - acc: 0.8891 - val_loss: 0.2985 - val_acc: 0.8730
#
# Epoch 00018: val_acc did not improve from 0.88333
# Epoch 19/50
# 230/230 [==============================] - 299s 1s/step - loss: 0.2978 - acc: 0.8755 - val_loss: 0.3055 - val_acc: 0.8660
#
# Epoch 00019: val_acc did not improve from 0.88333
# Epoch 20/50
# 230/230 [==============================] - 298s 1s/step - loss: 0.2668 - acc: 0.8946 - val_loss: 0.3255 - val_acc: 0.8538
#
# Epoch 00020: val_acc did not improve from 0.88333
# Epoch 21/50
# 230/230 [==============================] - 297s 1s/step - loss: 0.2706 - acc: 0.8967 - val_loss: 0.2756 - val_acc: 0.8830
#
# Epoch 00021: val_acc did not improve from 0.88333
# Epoch 22/50
# 230/230 [==============================] - 299s 1s/step - loss: 0.2763 - acc: 0.8929 - val_loss: 0.2635 - val_acc: 0.8885
#
# Epoch 00022: val_acc improved from 0.88333 to 0.88853, saving model to Damaged_densenet_final.h5
# Epoch 23/50
# 230/230 [==============================] - 298s 1s/step - loss: 0.2698 - acc: 0.8929 - val_loss: 0.2940 - val_acc: 0.8735
#
# Epoch 00023: val_acc did not improve from 0.88853
# Epoch 24/50
# 230/230 [==============================] - 298s 1s/step - loss: 0.2477 - acc: 0.9016 - val_loss: 0.2811 - val_acc: 0.8818
#
# Epoch 00024: val_acc did not improve from 0.88853
# Epoch 25/50
# 230/230 [==============================] - 298s 1s/step - loss: 0.2665 - acc: 0.8924 - val_loss: 0.2954 - val_acc: 0.8725
#
# Epoch 00025: val_acc did not improve from 0.88853
# Epoch 26/50
# 230/230 [==============================] - 296s 1s/step - loss: 0.2585 - acc: 0.9000 - val_loss: 0.2911 - val_acc: 0.8774
#
# Epoch 00026: val_acc did not improve from 0.88853
# Epoch 27/50
# 230/230 [==============================] - 298s 1s/step - loss: 0.2605 - acc: 0.8984 - val_loss: 0.3072 - val_acc: 0.8665
#
# Epoch 00027: val_acc did not improve from 0.88853
# Epoch 28/50
# 230/230 [==============================] - 297s 1s/step - loss: 0.2470 - acc: 0.8984 - val_loss: 0.3049 - val_acc: 0.8673
#
# Epoch 00028: val_acc did not improve from 0.88853
# Epoch 29/50
# 230/230 [==============================] - 297s 1s/step - loss: 0.2350 - acc: 0.9125 - val_loss: 0.2674 - val_acc: 0.8873
#
# Epoch 00029: val_acc did not improve from 0.88853
# Epoch 30/50
# 230/230 [==============================] - 297s 1s/step - loss: 0.2525 - acc: 0.8984 - val_loss: 0.2774 - val_acc: 0.8837
#
# Epoch 00030: val_acc did not improve from 0.88853
# Epoch 31/50
# 230/230 [==============================] - 299s 1s/step - loss: 0.2395 - acc: 0.9071 - val_loss: 0.3283 - val_acc: 0.8567
#
# Epoch 00031: val_acc did not improve from 0.88853
# Epoch 32/50
# 230/230 [==============================] - 298s 1s/step - loss: 0.2448 - acc: 0.8973 - val_loss: 0.3050 - val_acc: 0.8675
#
# Epoch 00032: val_acc did not improve from 0.88853
# Epoch 33/50
# 230/230 [==============================] - 298s 1s/step - loss: 0.2483 - acc: 0.9000 - val_loss: 0.3299 - val_acc: 0.8531
#
# Epoch 00033: val_acc did not improve from 0.88853
# Epoch 34/50
# 230/230 [==============================] - 297s 1s/step - loss: 0.2402 - acc: 0.9016 - val_loss: 0.4057 - val_acc: 0.8225
#
# Epoch 00034: val_acc did not improve from 0.88853
# Epoch 35/50
# 230/230 [==============================] - 299s 1s/step - loss: 0.2348 - acc: 0.9005 - val_loss: 0.3320 - val_acc: 0.8575
#
# Epoch 00035: val_acc did not improve from 0.88853
# Epoch 36/50
# 230/230 [==============================] - 296s 1s/step - loss: 0.2323 - acc: 0.9065 - val_loss: 0.4582 - val_acc: 0.8035
#
# Epoch 00036: val_acc did not improve from 0.88853
# Epoch 37/50
# 230/230 [==============================] - 281s 1s/step - loss: 0.2151 - acc: 0.9152 - val_loss: 0.3322 - val_acc: 0.8594
#
# Epoch 00037: val_acc did not improve from 0.88853
# Epoch 38/50
# 230/230 [==============================] - 280s 1s/step - loss: 0.2228 - acc: 0.9071 - val_loss: 0.3341 - val_acc: 0.8567
#
# Epoch 00038: val_acc did not improve from 0.88853
# Epoch 39/50
# 230/230 [==============================] - 281s 1s/step - loss: 0.2304 - acc: 0.9060 - val_loss: 0.3243 - val_acc: 0.8606
#
# Epoch 00039: val_acc did not improve from 0.88853
# Epoch 40/50
# 230/230 [==============================] - 282s 1s/step - loss: 0.2219 - acc: 0.9000 - val_loss: 0.3642 - val_acc: 0.8426
#
# Epoch 00040: val_acc did not improve from 0.88853
# Epoch 41/50
# 230/230 [==============================] - 280s 1s/step - loss: 0.2177 - acc: 0.9082 - val_loss: 0.3888 - val_acc: 0.8293
#
# Epoch 00041: val_acc did not improve from 0.88853
# Epoch 42/50
# 230/230 [==============================] - 280s 1s/step - loss: 0.2225 - acc: 0.9130 - val_loss: 0.3289 - val_acc: 0.8556
#
# Epoch 00042: val_acc did not improve from 0.88853
# Epoch 43/50
# 230/230 [==============================] - 280s 1s/step - loss: 0.2231 - acc: 0.9130 - val_loss: 0.3119 - val_acc: 0.8661
#
# Epoch 00043: val_acc did not improve from 0.88853
# Epoch 44/50
# 230/230 [==============================] - 282s 1s/step - loss: 0.2123 - acc: 0.9190 - val_loss: 0.3297 - val_acc: 0.8593
#
# Epoch 00044: val_acc did not improve from 0.88853
# Epoch 45/50
# 230/230 [==============================] - 282s 1s/step - loss: 0.2255 - acc: 0.9136 - val_loss: 0.3267 - val_acc: 0.8587
#
# Epoch 00045: val_acc did not improve from 0.88853
# Epoch 46/50
# 230/230 [==============================] - 282s 1s/step - loss: 0.1939 - acc: 0.9245 - val_loss: 0.3771 - val_acc: 0.8363
#
# Epoch 00046: val_acc did not improve from 0.88853
# Epoch 47/50
# 230/230 [==============================] - 282s 1s/step - loss: 0.2104 - acc: 0.9136 - val_loss: 0.3297 - val_acc: 0.8597
#
# Epoch 00047: val_acc did not improve from 0.88853
# Epoch 48/50
# 230/230 [==============================] - 282s 1s/step - loss: 0.2040 - acc: 0.9179 - val_loss: 0.3240 - val_acc: 0.8621
#
# Epoch 00048: val_acc did not improve from 0.88853
# Epoch 49/50
# 230/230 [==============================] - 282s 1s/step - loss: 0.2017 - acc: 0.9228 - val_loss: 0.3747 - val_acc: 0.8399
#
# Epoch 00049: val_acc did not improve from 0.88853
# Epoch 50/50
# 230/230 [==============================] - 282s 1s/step - loss: 0.2175 - acc: 0.9054 - val_loss: 0.4024 - val_acc: 0.8238
#
# Epoch 00050: val_acc did not improve from 0.88853

# %%
def car_categories_gate(image_path, model):
    urllib.request.urlretrieve(image_path, 'save.jpg') # or other way to upload image
    img = load_img('save.jpg', target_size=(256, 256)) # this is a PIL image 
    x = img_to_array(img) # this is a Numpy array with shape (3, 256, 256)
    x = x.reshape((1,) + x.shape)/255 # this is a Numpy array with shape (1, 3, 256, 256)
    pred = model.predict(x)
    plt.imshow(img)
    plt.show()
    print ("Validating that damage exists...")
    print (pred)
    if pred[0][0] <=.5:
        print ("Validation complete - proceed to location and severity determination")
    else:
        print ("Are you sure that your car is damaged? Please submit another picture of the damage.")
        print ("Hint: Try zooming in/out, using a different angle or different lighting")

# %%
car_categories_gate('https://www.nerdwallet.com/blog/wp-content/uploads/2015/12/exterior-car-damage-384x233.jpg', model_final)
# Out:
# Validating that damage exists...
# [[0.92693484]]
# Are you sure that your car is damaged? Please submit another picture of the damage.
# Hint: Try zooming in/out, using a different angle or different lighting

# %%
car_categories_gate('http://1.bp.blogspot.com/-ToQS-qIxYbo/UDNuV5OcVQI/AAAAAAAABdo/tjeQywWiOo0/s200/Key+scratch.jpg', model_final)
# Out:
# Validating that damage exists...
# [[0.7743331]]
# Are you sure that your car is damaged? Please submit another picture of the damage.
# Hint: Try zooming in/out, using a different angle or different lighting

# %%
car_categories_gate('https://st.motortrend.com/uploads/sites/10/2017/02/2017-ford-taurus-sho-sedan-angular-front.png', model_final)
# Out:
# Validating that damage exists...
# [[0.999824]]
# Are you sure that your car is damaged? Please submit another picture of the damage.
# Hint: Try zooming in/out, using a different angle or different lighting

# %%
car_categories_gate('https://www.cars.com/cstatic-images/car-pictures/xl/usc70fos131c021001.png',model_final)
# Out:
# Validating that damage exists...
# [[0.9988175]]
# Are you sure that your car is damaged? Please submit another picture of the damage.
# Hint: Try zooming in/out, using a different angle or different lighting

# %%
car_categories_gate('https://upload.wikimedia.org/wikipedia/en/thumb/1/16/Crash_Bandicoot.png/220px-Crash_Bandicoot.png',model_final)
# Out:
# Validating that damage exists...
# [[0.9692322]]
# Are you sure that your car is damaged? Please submit another picture of the damage.
# Hint: Try zooming in/out, using a different angle or different lighting

# %%
car_categories_gate('https://boygeniusreport.files.wordpress.com/2017/09/dented-car.jpg?quality=98&strip=all&w=782',model_final)
# Out:
# Validating that damage exists...
# [[0.02163259]]
# Validation complete - proceed to location and severity determination

# %%
car_categories_gate('https://img-aws.ehowcdn.com/600x400/cpi.studiod.com/www_ehow_com/i.ehow.com/images/a02/7p/bi/repair-car-dent-800x800.jpg',model_final)
# Out:
# Validating that damage exists...
# [[0.14210317]]
# Validation complete - proceed to location and severity determination

# %%
car_categories_gate('https://cf.ltkcdn.net/cars/images/std/71228-400x284-Cardents.jpg',model_final)
# Out:
# Validating that damage exists...
# [[0.0873558]]
# Validation complete - proceed to location and severity determination

# %%
car_categories_gate('https://media.wired.com/photos/5b86fce8900cb57bbfd1e7ee/master/pass/Jaguar_I-PACE_S_Indus-Silver_065.jpg',model_final)
# Out:
# Validating that damage exists...
# [[0.99946755]]
# Are you sure that your car is damaged? Please submit another picture of the damage.
# Hint: Try zooming in/out, using a different angle or different lighting

# %%
car_categories_gate('https://images-na.ssl-images-amazon.com/images/I/51dhUSCzBfL.jpg',model_final)
# Out:
# Validating that damage exists...
# [[0.9352682]]
# Are you sure that your car is damaged? Please submit another picture of the damage.
# Hint: Try zooming in/out, using a different angle or different lighting

# %%
car_categories_gate('https://encrypted-tbn0.gstatic.com/images?q=tbn:ANd9GcTpG_0UHGpCG8FE9ggGu2YOx39eBgJnTIDEUmS6g5V38Ltfn7Mz',model_final)
# Out:
# Validating that damage exists...
# [[0.288748]]
# Validation complete - proceed to location and severity determination
