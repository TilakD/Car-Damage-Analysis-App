# %%
import os
os.environ["CUDA_VISIBLE_DEVICES"] = "0,3"

# %%
from keras.layers import Conv2D, MaxPooling2D, ZeroPadding2D
from keras.layers import Dense, Activation, Dropout, Flatten
from keras import optimizers
from keras.models import Sequential,load_model
from keras.preprocessing.image import ImageDataGenerator,load_img,img_to_array
import numpy as np 
from keras.callbacks import ModelCheckpoint, History
import os
import urllib
import matplotlib.pyplot as plt
# %matplotlib inline
import json
import seaborn as sns 
from keras import applications
from keras.models import Sequential, Model 
from keras.callbacks import ModelCheckpoint, LearningRateScheduler, TensorBoard, EarlyStopping
# Out:
# Using TensorFlow backend.

# %%
img_width = 256
img_height = 256
train_data_dir = 'training'
valid_data_dir = 'validation'
fine_tuned_model_path = 'ft_model.h5'
train_samples = [len(os.listdir(train_data_dir+'/'+i)) for i in sorted(os.listdir(train_data_dir))]
nb_train_samples = sum(train_samples)
print(nb_train_samples)
validation_samples = [len(os.listdir(valid_data_dir+'/'+i)) for i in sorted(os.listdir(valid_data_dir))]
nb_validation_samples = sum(validation_samples)
print(nb_validation_samples)
epochs=150
batch_size = 8
# Out:
# 979
# 171

# %%
model = applications.DenseNet201(weights = "imagenet", include_top=False, input_shape = (img_width, img_height, 3))

# %%
model.layers[703]

# %%
for layer in model.layers[:703]:
    layer.trainable = False

# %%
x = model.output
x = Flatten()(x)
x = Dense(256, activation="relu")(x)
x = Dropout(0.5)(x)
x = Dense(256, activation="relu")(x)
predictions = Dense(3, activation="softmax")(x)

model_final = Model(input = model.input, output = predictions)

model_final.compile(loss = "categorical_crossentropy", optimizer = optimizers.SGD(lr=0.00001, momentum=0.9), metrics=["accuracy"])

train_datagen = ImageDataGenerator(
rescale = 1./255,
horizontal_flip = True,
fill_mode = "nearest",
zoom_range = 0.2,
width_shift_range = 0.2,
height_shift_range=0.2,
shear_range=0.2,
rotation_range=40)

test_datagen = ImageDataGenerator(
rescale = 1./255,
horizontal_flip = True,
fill_mode = "nearest",
zoom_range = 0.2,
width_shift_range = 0.2,
height_shift_range=0.2,
shear_range=0.2,
rotation_range=40)

train_generator = train_datagen.flow_from_directory(
train_data_dir,
target_size = (img_height, img_width),
batch_size = batch_size, 
class_mode = "categorical")

validation_generator = test_datagen.flow_from_directory(
valid_data_dir,
target_size = (img_height, img_width),
class_mode = "categorical")

checkpoint = ModelCheckpoint("Location_densenet_final.h5", monitor='val_acc', verbose=1, save_best_only=True, save_weights_only=False, mode='auto', period=1)

#early = EarlyStopping(monitor='val_acc', min_delta=0, patience=10, verbose=1, mode='auto')

model_final.fit_generator(
train_generator,
samples_per_epoch = nb_train_samples,
epochs = epochs,
validation_data = validation_generator,
nb_val_samples = nb_validation_samples,
callbacks = [checkpoint]) #,early
# Out:
# /home/dtilak/.local/lib/python3.5/site-packages/ipykernel_launcher.py:8: UserWarning: Update your `Model` call to the Keras 2 API: `Model(outputs=Tensor("de..., inputs=Tensor("in...)`
# Found 979 images belonging to 3 classes.
# Found 171 images belonging to 3 classes.
# /home/dtilak/.local/lib/python3.5/site-packages/ipykernel_launcher.py:53: UserWarning: The semantics of the Keras 2 argument `steps_per_epoch` is not the same as the Keras 1 argument `samples_per_epoch`. `steps_per_epoch` is the number of batches to draw from the generator at each epoch. Basically steps_per_epoch = samples_per_epoch/batch_size. Similarly `nb_val_samples`->`validation_steps` and `val_samples`->`steps` arguments have changed. Update your method calls accordingly.
# /home/dtilak/.local/lib/python3.5/site-packages/ipykernel_launcher.py:53: UserWarning: Update your `fit_generator` call to the Keras 2 API: `fit_generator(<keras_pre..., steps_per_epoch=122, validation_steps=171, validation_data=<keras_pre..., epochs=150, callbacks=[<keras.ca...)`
# Epoch 1/150
# 122/122 [==============================] - 85s 697ms/step - loss: 1.2523 - acc: 0.3934 - val_loss: 1.1100 - val_acc: 0.3980
#
# Epoch 00001: val_acc improved from -inf to 0.39803, saving model to Location_densenet_final.h5
# Epoch 2/150
# 122/122 [==============================] - 71s 582ms/step - loss: 1.1683 - acc: 0.4006 - val_loss: 1.0567 - val_acc: 0.4470
#
# Epoch 00002: val_acc improved from 0.39803 to 0.44705, saving model to Location_densenet_final.h5
# Epoch 3/150
# 122/122 [==============================] - 71s 586ms/step - loss: 1.0958 - acc: 0.4536 - val_loss: 1.0460 - val_acc: 0.4576
#
# Epoch 00003: val_acc improved from 0.44705 to 0.45762, saving model to Location_densenet_final.h5
# Epoch 4/150
# 122/122 [==============================] - 73s 599ms/step - loss: 1.0774 - acc: 0.4464 - val_loss: 1.0247 - val_acc: 0.4808
#
# Epoch 00004: val_acc improved from 0.45762 to 0.48077, saving model to Location_densenet_final.h5
# Epoch 5/150
# 122/122 [==============================] - 73s 602ms/step - loss: 1.0507 - acc: 0.4737 - val_loss: 1.0167 - val_acc: 0.4945
#
# Epoch 00005: val_acc improved from 0.48077 to 0.49447, saving model to Location_densenet_final.h5
# Epoch 6/150
# 122/122 [==============================] - 73s 595ms/step - loss: 1.0309 - acc: 0.5031 - val_loss: 0.9995 - val_acc: 0.5092
#
# Epoch 00006: val_acc improved from 0.49447 to 0.50915, saving model to Location_densenet_final.h5
# Epoch 7/150
# 122/122 [==============================] - 70s 577ms/step - loss: 1.0294 - acc: 0.4925 - val_loss: 1.0007 - val_acc: 0.5045
#
# Epoch 00007: val_acc did not improve from 0.50915
# Epoch 8/150
# 122/122 [==============================] - 71s 580ms/step - loss: 0.9633 - acc: 0.5434 - val_loss: 0.9742 - val_acc: 0.5431
#
# Epoch 00008: val_acc improved from 0.50915 to 0.54308, saving model to Location_densenet_final.h5
# Epoch 9/150
# 122/122 [==============================] - 71s 578ms/step - loss: 0.9585 - acc: 0.5335 - val_loss: 0.9578 - val_acc: 0.5452
#
# Epoch 00009: val_acc improved from 0.54308 to 0.54525, saving model to Location_densenet_final.h5
# Epoch 10/150
# 122/122 [==============================] - 74s 606ms/step - loss: 0.9643 - acc: 0.5297 - val_loss: 0.9374 - val_acc: 0.5713
#
# Epoch 00010: val_acc improved from 0.54525 to 0.57125, saving model to Location_densenet_final.h5
# Epoch 11/150
# 122/122 [==============================] - 71s 583ms/step - loss: 0.9407 - acc: 0.5505 - val_loss: 0.9386 - val_acc: 0.5667
#
# Epoch 00011: val_acc did not improve from 0.57125
# Epoch 12/150
# 122/122 [==============================] - 71s 579ms/step - loss: 0.9465 - acc: 0.5499 - val_loss: 0.9277 - val_acc: 0.5782
#
# Epoch 00012: val_acc improved from 0.57125 to 0.57824, saving model to Location_densenet_final.h5
# Epoch 13/150
# 122/122 [==============================] - 71s 581ms/step - loss: 0.9495 - acc: 0.5495 - val_loss: 0.9282 - val_acc: 0.5749
#
# Epoch 00013: val_acc did not improve from 0.57824
# Epoch 14/150
# 122/122 [==============================] - 73s 597ms/step - loss: 0.9230 - acc: 0.5454 - val_loss: 0.8953 - val_acc: 0.6031
#
# Epoch 00014: val_acc improved from 0.57824 to 0.60313, saving model to Location_densenet_final.h5
# Epoch 15/150
# 122/122 [==============================] - 70s 577ms/step - loss: 0.5128 - acc: 0.7934 - val_loss: 0.9209 - val_acc: 0.6431
#
# Epoch 00137: val_acc did not improve from 0.66255
# Epoch 138/150
# 122/122 [==============================] - 73s 596ms/step - loss: 0.5136 - acc: 0.7903 - val_loss: 0.9381 - val_acc: 0.6449
#
# Epoch 00138: val_acc did not improve from 0.66255
# Epoch 139/150
# 122/122 [==============================] - 72s 594ms/step - loss: 0.5553 - acc: 0.7678 - val_loss: 0.9111 - val_acc: 0.6392
#
# Epoch 00139: val_acc did not improve from 0.66255
# Epoch 140/150
# 122/122 [==============================] - 71s 584ms/step - loss: 0.5347 - acc: 0.7828 - val_loss: 0.9103 - val_acc: 0.6229
#
# Epoch 00140: val_acc did not improve from 0.66255
# Epoch 141/150
# 122/122 [==============================] - 70s 578ms/step - loss: 0.5409 - acc: 0.7725 - val_loss: 0.9045 - val_acc: 0.6398
#
# Epoch 00141: val_acc did not improve from 0.66255
# Epoch 142/150
# 122/122 [==============================] - 72s 590ms/step - loss: 0.5170 - acc: 0.8002 - val_loss: 0.9286 - val_acc: 0.6377
#
# Epoch 00142: val_acc did not improve from 0.66255
# Epoch 143/150
# 122/122 [==============================] - 72s 594ms/step - loss: 0.5453 - acc: 0.7852 - val_loss: 0.9308 - val_acc: 0.6302
#
# Epoch 00143: val_acc did not improve from 0.66255
# Epoch 144/150
# 122/122 [==============================] - 70s 577ms/step - loss: 0.5468 - acc: 0.7691 - val_loss: 0.9249 - val_acc: 0.6418
#
# Epoch 00144: val_acc did not improve from 0.66255
# Epoch 145/150
# 122/122 [==============================] - 71s 582ms/step - loss: 0.5214 - acc: 0.7886 - val_loss: 0.9128 - val_acc: 0.6462
#
# Epoch 00145: val_acc did not improve from 0.66255
# Epoch 146/150
# 122/122 [==============================] - 71s 580ms/step - loss: 0.5137 - acc: 0.7780 - val_loss: 0.9497 - val_acc: 0.6338
#
# Epoch 00146: val_acc did not improve from 0.66255
# Epoch 147/150
# 122/122 [==============================] - 74s 610ms/step - loss: 0.5311 - acc: 0.7814 - val_loss: 0.9248 - val_acc: 0.6480
#
# Epoch 00147: val_acc did not improve from 0.66255
# Epoch 148/150
# 122/122 [==============================] - 71s 585ms/step - loss: 0.5354 - acc: 0.7896 - val_loss: 0.9218 - val_acc: 0.6457
#
# Epoch 00148: val_acc did not improve from 0.66255
# Epoch 149/150
# 122/122 [==============================] - 71s 582ms/step - loss: 0.5455 - acc: 0.7773 - val_loss: 0.9413 - val_acc: 0.6302
#
# Epoch 00149: val_acc did not improve from 0.66255
# Epoch 150/150
# 122/122 [==============================] - 70s 572ms/step - loss: 0.4992 - acc: 0.7893 - val_loss: 0.9152 - val_acc: 0.6434
#
# Epoch 00150: val_acc did not improve from 0.66255

# %%
def location_estimator(image_path, model):
    print ("Determining location of damage...")
    urllib.request.urlretrieve(image_path, 'save.jpg') # or other way to upload image
    img = load_img('save.jpg', target_size=(256, 256)) # this is a PIL image 
    x = img_to_array(img) # this is a Numpy array with shape (3, 256, 256)
    x = x.reshape((1,) + x.shape)/255 # this is a Numpy array with shape (1, 3, 256, 256)
    pred = model.predict(x)
    pred_label = np.argmax(pred, axis=1)
    print(pred_label)
    plt.imshow(img)
    plt.show()
    d = {0: 'Front', 1: 'Rear', 2: 'Side'}
    for key in d.keys():
        if pred_label[0] == key:
            print ("Assessment: {} damage to vehicle".format(d[key]))
    print ("Location assessment complete.")

# %%
location_estimator('data:image/jpeg;base64,...',model_final)
# Out:
# Determining location of damage...
# [2]
# Assessment: Side damage to vehicle
# Location assessment complete.

# %%
location_estimator('https://c8.alamy.com/comp/EKAP5C/car-accident-damage-on-rear-end-usa-EKAP5C.jpg',model_final)
# Out:
# Determining location of damage...
# [1]
# Assessment: Rear damage to vehicle
# Location assessment complete.

# %%
location_estimator('data:image/jpeg;base64,...',model_final)
# Out:
# Determining location of damage...
# [0]
# Assessment: Front damage to vehicle
# Location assessment complete.

# %%
location_estimator('http://www.sturtevantauto.com/Content/files/CarBodyDamage.jpg', model_final)
# Out:
# Determining location of damage...
# [2]
# Assessment: Side damage to vehicle
# Location assessment complete.

# %%
location_estimator('http://1.bp.blogspot.com/-ToQS-qIxYbo/UDNuV5OcVQI/AAAAAAAABdo/tjeQywWiOo0/s200/Key+scratch.jpg', model_final)
# Out:
# Determining location of damage...
# [2]
# Assessment: Side damage to vehicle
# Location assessment complete.

# %%
location_estimator('https://www.libertymutual.com/insurance-content/copy/claims/types-of-car-damage/severe-car-damage.jpg?v=2015030112332273', model_final)
# Out:
# Determining location of damage...
# [0]
# Assessment: Front damage to vehicle
# Location assessment complete.

# %%
location_estimator('data:image/jpeg;base64,...', model_final)
# Out:
# Determining location of damage...
# [0]
# Assessment: Front damage to vehicle
# Location assessment complete.

# %%
location_estimator('data:image/jpeg;base64,...', model_final)
# Out:
# Determining location of damage...
# [1]
# Assessment: Rear damage to vehicle
# Location assessment complete.

# %%
location_estimator('https://www.side.cr/wp-content/uploads/2018/09/Connecticut-Sell-Damaged-Car.jpg', model_final)
# Out:
# Determining location of damage...
# [2]
# Assessment: Side damage to vehicle
# Location assessment complete.

# %%
location_estimator('data:image/jpeg;base64,...', model_final)
# Out:
# Determining location of damage...
# [0]
# Assessment: Front damage to vehicle
# Location assessment complete.

# %%
location_estimator('https://encrypted-tbn0.gstatic.com/images?q=tbn:ANd9GcS9Zi5chHQrhlAxtYupxm5wH2SvYDj2T47XJ3ckLI735NjMi2xm9Q', model_final)
# Out:
# Determining location of damage...
# [0]
# Assessment: Front damage to vehicle
# Location assessment complete.

# %%
location_estimator('https://www.autoauctionmall.com/learning-center/contents/uploads/2015/10/damaged-car.jpg', model_final)
# Out:
# Determining location of damage...
# [0]
# Assessment: Front damage to vehicle
# Location assessment complete.

# %%
location_estimator('https://encrypted-tbn0.gstatic.com/images?q=tbn:ANd9GcQRBUPvifCXSM14dO8WvFcoAQJOVQiRC8ul3YxfvMEb2lFsC0D2', model_final)
# Out:
# Determining location of damage...
# [1]
# Assessment: Rear damage to vehicle
# Location assessment complete.

# %%
location_estimator('https://encrypted-tbn0.gstatic.com/images?q=tbn:ANd9GcThpYaPbP4xKXPLaTAP-p3BnkgyElfOKbV5o6VNaqt40ZjvevyO', model_final)
# Out:
# Determining location of damage...
# [0]
# Assessment: Front damage to vehicle
# Location assessment complete.
